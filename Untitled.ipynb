# %%
# %pip install ultralyticsplus==0.0.28 ultralytics==8.0.43
# Out:
# Collecting ultralyticsplus==0.0.28
#   Downloading ultralyticsplus-0.0.28-py3-none-any.whl (11 kB)
# Collecting ultralytics==8.0.43
#   Downloading ultralytics-8.0.43-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: huggingface-hub>=0.12.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralyticsplus==0.0.28) (0.15.1)
# Collecting fire (from ultralyticsplus==0.0.28)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sahi<0.12.0,>=0.11.11 (from ultralyticsplus==0.0.28)
#   Obtaining dependency information for sahi<0.12.0,>=0.11.11 from https://files.pythonhosted.org/packages/bf/2b/026f0861137499edca43263679f9e4ce21314b67c34c8d74c12f2833b8c3/sahi-0.11.14-py3-none-any.whl.metadata
#   Downloading sahi-0.11.14-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralyticsplus==0.0.28) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (1.24.3)
# Collecting opencv-python>=4.6.0 (from ultralytics==8.0.43)
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/a1/f6/57de91ea40c670527cd47a6548bf2cbedc68cec57c041793b256356abad7/opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (9.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (2.0.1)
# Collecting torchvision>=0.8.1 (from ultralytics==8.0.43)
#   Obtaining dependency information for torchvision>=0.8.1 from https://files.pythonhosted.org/packages/dd/48/85ef87f1548620d7c3743cbe135b90d8cf673fc7b8594361917558d765b6/torchvision-0.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading torchvision-0.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (4.65.0)
# Collecting tensorboard>=2.4.1 (from ultralytics==8.0.43)
#   Obtaining dependency information for tensorboard>=2.4.1 from https://files.pythonhosted.org/packages/69/38/fb2ac9c4c8efbe020ae88f6772be87d51ef18526ac541fc3393786b7c45a/tensorboard-2.15.0-py3-none-any.whl.metadata
#   Downloading tensorboard-2.15.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (0.12.2)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (5.9.0)
# Collecting thop>=0.1.1 (from ultralytics==8.0.43)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel>=0.38.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from ultralytics==8.0.43) (0.38.4)
# Collecting sentry-sdk (from ultralytics==8.0.43)
#   Obtaining dependency information for sentry-sdk from https://files.pythonhosted.org/packages/63/25/d22e1e152e4eac10d39d9132d7b5f1ea4bdfa0b9a1d65fc606a7b90aeefb/sentry_sdk-1.32.0-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.28) (3.9.0)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.28) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.28) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.28) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.2.2->ultralytics==8.0.43) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas->ultralyticsplus==0.0.28) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.43) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.43) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.43) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics==8.0.43) (2023.7.22)
# Collecting shapely>=1.8.0 (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.28)
#   Obtaining dependency information for shapely>=1.8.0 from https://files.pythonhosted.org/packages/2c/b1/ca09649b4abe06366d41e90c3eee95a7741657404404a63bd0e8b53e32b8/shapely-2.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading shapely-2.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Collecting pybboxes==0.1.6 (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.28)
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting terminaltables (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.28)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.28) (8.0.4)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/bb/1c/4741e490b93488e077e36543b0acbfece41314b5a1ffae05bc7e2e9b3375/grpcio-1.59.0-cp311-cp311-macosx_10_10_universal2.whl.metadata
#   Downloading grpcio-1.59.0-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/39/7c/2e4fa55a99f83ef9ef229ac5d59c44ceb90e2d0145711590c0fa39669f32/google_auth-2.23.3-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for google-auth-oauthlib<2,>=0.5 from https://files.pythonhosted.org/packages/ce/33/a907b4b67245647746dde8d61e1643ef5d210c88e090d491efd89eff9f95/google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.43) (3.4.1)
# Collecting protobuf<4.24,>=3.19.6 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for protobuf<4.24,>=3.19.6 from https://files.pythonhosted.org/packages/cb/d3/a164038605494d49acc4f9cda1c0bc200b96382c53edd561387263bb181d/protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.43) (68.0.0)
# Requirement already satisfied: six>1.9 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.43) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from tensorboard>=2.4.1->ultralytics==8.0.43) (2.2.3)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics==8.0.43) (1.11.1)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics==8.0.43) (3.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from torch>=1.7.0->ultralytics==8.0.43) (3.1.2)
# Collecting torch>=1.7.0 (from ultralytics==8.0.43)
#   Obtaining dependency information for torch>=1.7.0 from https://files.pythonhosted.org/packages/7b/7c/4d8728e6f8dbe2b8af054bd92c290d94c633270443514e3ee4b768125cf9/torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata (24 kB)
# Collecting termcolor (from fire->ultralyticsplus==0.0.28)
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.43)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.43) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.43)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.43)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics==8.0.43) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.7.0->ultralytics==8.0.43) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.43) (0.4.8)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.43)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading opencv_python-4.8.1.78-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 690.7 kB/s eta 0:00:0000:0100:02
# Downloading sahi-0.11.14-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 642.0 kB/s eta 0:00:00a 0:00:01
# Downloading tensorboard-2.15.0-py3-none-any.whl (5.6 MB)
#    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/5.6 MB 961.6 kB/s eta 0:00:06

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('foduucom/web-form-ui-field-detection')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = './02_preview2.png'

# perform inference
results = model.predict(image)

# observe results
print(results[0].boxes)
print(results[0])
render = render_result(model=model, image=image, result=results[0])
render.show()
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.9.18 torch-2.1.0 CPU
# Model summary (fused): 168 layers, 11140677 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /Users/alacartaapp/dev/tutorials/model/02_preview2.png: 640x352 1 button, 1 email-input, 1 password, 55.3ms
# Speed: 0.4ms preprocess, 55.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[2.40000e+01, 4.31000e+02, 4.32000e+02, 4.95000e+02, 6.78215e-01, 1.40000e+01],
#         [3.00000e+01, 5.93000e+02, 4.26000e+02, 6.61000e+02, 6.65028e-01, 4.00000e+00],
#         [2.50000e+01, 5.08000e+02, 4.35000e+02, 5.67000e+02, 4.58882e-01, 2.60000e+01]])
# tensor([[2.40000e+01, 4.31000e+02, 4.32000e+02, 4.95000e+02, 6.78215e-01, 1.40000e+01],
#         [3.00000e+01, 5.93000e+02, 4.26000e+02, 6.61000e+02, 6.65028e-01, 4.00000e+00],
#         [2.50000e+01, 5.08000e+02, 4.35000e+02, 5.67000e+02, 4.58882e-01, 2.60000e+01]])
